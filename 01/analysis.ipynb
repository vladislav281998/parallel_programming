# %%
import os                           # For file handling
import re                           # For regular expressions
import subprocess                   # For running shell commands
from tabulate import tabulate       # For pretty printing of tables
import numpy as np                  # For numerical operations
import matplotlib.pyplot as plt     # For plotting   
import pandas as pd                 # For data manipulation

# %%
# Compile C files with various optimization levels
def compile_c_files(files, opt_lvls):
    for f in files:
        print(f"Compiling {f}")
        for o in opt_lvls:
            print(f"\tUsing Optimization Level: {o}")
            exe = f.split('.')[0] + "." + o.replace('-', '')
            try:
                subprocess.run(["gcc-13", f, "-o", exe, o, "-fopenmp"], check=True) # Change gcc-13 to gcc if you are using a different version!!
            except subprocess.CalledProcessError as e:
                print(f"Error during compilation of {f} with optimization {o}: {e}")

def execute_benchmarks(files, opt_lvls, num_threads, run_number):
    benchmarks = []
    with open('execution_times.txt', 'a') as file:
        for f in files:
            for o in opt_lvls:
                for nc in range(1, num_threads + 1):
                    exe = "./" + f.split('.')[0] + "." + o.replace('-', '')
                    print(f"Running {exe} using {nc} Cores")
                    env = os.environ.copy()
                    env["OMP_NUM_THREADS"] = str(nc)
                    try:
                        result = subprocess.check_output([exe], env=env)
                        result_str = result.decode("utf-8")
                        time = result_str.split(' ')[3]
                        print(f"\tTime taken {time} sec")
                        benchmarks.append((run_number, f, o, nc, f"{time} sec"))
                        file.write(f"{run_number}, {f}, {o}, {nc}, {time} sec\n")
                    except subprocess.CalledProcessError as e:
                        print(f"Error during execution of {exe} with {nc} cores: {e}")
    print(tabulate(benchmarks, headers=["Run", "FileName", "Optimization Level", "Number of Threads", "Time"], tablefmt="simple"))

def run_tests_with_optimization_levels(total_runs, num_threads):
    all_files = os.listdir(".")
    pattern = re.compile(".+\.c$")
    files = [file for file in all_files if pattern.match(file)]
    opt_lvls = ["-O0", "-O1", "-O2", "-O3", "-Ofast", "-Os"]

    print(f"Running Tests for Files: {files}")
    for run_number in range(1, total_runs + 1):
        print(f"Starting Run {run_number}")
        compile_c_files(files, opt_lvls)
        execute_benchmarks(files, opt_lvls, num_threads, run_number)

# %%
# Run the tests
run_tests_with_optimization_levels(5, 12)
# Out:
# Running Tests for Files: ['slow.c', 'fast.c', 'medium.c']
# Starting Run 1
# Compiling slow.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Compiling fast.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Compiling medium.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Running ./slow.O0 using 1 Cores
# 	Time taken 0.6053 sec
# Running ./slow.O0 using 2 Cores
# 	Time taken 1.1361 sec
# Running ./slow.O0 using 3 Cores
# 	Time taken 6.1665 sec
# Running ./slow.O0 using 4 Cores
# 	Time taken 1.7311 sec
# Running ./slow.O0 using 5 Cores
# 	Time taken 1.2980 sec
# Running ./slow.O0 using 6 Cores
# 	Time taken 1.7094 sec
# Running ./slow.O0 using 7 Cores
# 	Time taken 1.7056 sec
# Running ./slow.O0 using 8 Cores
# 	Time taken 1.7099 sec
# Running ./slow.O0 using 9 Cores
# 	Time taken 1.8539 sec
# Running ./slow.O0 using 10 Cores
# 	Time taken 2.1174 sec
# Running ./slow.O0 using 11 Cores
# 	Time taken 2.0872 sec
# Running ./slow.O0 using 12 Cores
# 	Time taken 2.0776 sec
# Running ./slow.O1 using 1 Cores
# 	Time taken 0.6139 sec
# Running ./slow.O1 using 2 Cores
# 	Time taken 1.3491 sec
# Running ./slow.O1 using 3 Cores
# 	Time taken 6.7334 sec
# Running ./slow.O1 using 4 Cores
# 	Time taken 1.6873 sec
# Running ./slow.O1 using 5 Cores
# 	Time taken 1.1151 sec
# Running ./slow.O1 using 6 Cores
# 	Time taken 1.6998 sec
# Running ./slow.O1 using 7 Cores
# 	Time taken 1.7006 sec
# Running ./slow.O1 using 8 Cores
# 	Time taken 1.7066 sec
# Running ./slow.O1 using 9 Cores
# 	Time taken 1.8621 sec
# Running ./slow.O1 using 10 Cores
# 	Time taken 2.2224 sec
# Running ./slow.O1 using 11 Cores
# 	Time taken 2.2507 sec
# Running ./slow.O1 using 12 Cores
# 	Time taken 2.1044 sec
# Running ./slow.O2 using 1 Cores
# 	Time taken 0.6129 sec
# Running ./slow.O2 using 2 Cores
# 	Time taken 1.0909 sec
# Running ./slow.O2 using 3 Cores
# 	Time taken 5.6812 sec
# Running ./slow.O2 using 4 Cores
# 	Time taken 1.5853 sec
# Running ./slow.O2 using 5 Cores
# 	Time taken 1.2907 sec
# Running ./slow.O2 using 6 Cores
# 	Time taken 1.7649 sec
# Running ./slow.O2 using 7 Cores
# 	Time taken 1.7719 sec
# Running ./slow.O2 using 8 Cores
# 	Time taken 1.8544 sec
# Running ./slow.O2 using 9 Cores
# 	Time taken 1.7731 sec
# Running ./slow.O2 using 10 Cores
# 	Time taken 2.1632 sec
# Running ./slow.O2 using 11 Cores
# 	Time taken 2.0082 sec
# Running ./slow.O2 using 12 Cores
# 	Time taken 2.2449 sec
# Running ./slow.O3 using 1 Cores
# 	Time taken 0.6125 sec
# Running ./slow.O3 using 2 Cores
# 	Time taken 1.1638 sec
# Running ./slow.O3 using 3 Cores
# 	Time taken 6.9850 sec
# Running ./slow.O3 using 4 Cores
# 	Time taken 1.7309 sec
# Running ./slow.O3 using 5 Cores
# 	Time taken 1.1103 sec
# Running ./slow.O3 using 6 Cores
# 	Time taken 1.7207 sec
# Running ./slow.O3 using 7 Cores
# 	Time taken 1.9970 sec
# Running ./slow.O3 using 8 Cores
# 	Time taken 1.7367 sec
# Running ./slow.O3 using 9 Cores
# 	Time taken 1.8425 sec
# Running ./slow.O3 using 10 Cores
# 	Time taken 2.0514 sec
# Running ./slow.O3 using 11 Cores
# 	Time taken 2.1148 sec
# Running ./slow.O3 using 12 Cores
# 	Time taken 2.1018 sec
# Running ./slow.Ofast using 1 Cores
# 	Time taken 0.6169 sec
# Running ./slow.Ofast using 2 Cores
# 	Time taken 1.0224 sec
# Running ./slow.Ofast using 3 Cores
# 	Time taken 7.0828 sec
# Running ./slow.Ofast using 4 Cores
# 	Time taken 1.6084 sec
# Running ./slow.Ofast using 5 Cores
# 	Time taken 1.1571 sec
# Running ./slow.Ofast using 6 Cores
# 	Time taken 1.6790 sec
# Running ./slow.Ofast using 7 Cores
# 	Time taken 1.9686 sec
# Running ./slow.Ofast using 8 Cores
# 	Time taken 1.7292 sec
# Running ./slow.Ofast using 9 Cores
# 	Time taken 1.9724 sec
# Running ./slow.Ofast using 10 Cores
# 	Time taken 2.1656 sec
# Running ./slow.Ofast using 11 Cores
# 	Time taken 2.1030 sec
# Running ./slow.Ofast using 12 Cores
# 	Time taken 2.3081 sec
# Running ./slow.Os using 1 Cores
# 	Time taken 0.6180 sec
# Running ./slow.Os using 2 Cores
# 	Time taken 1.0190 sec
# Running ./slow.Os using 3 Cores
# 	Time taken 6.6465 sec
# Running ./slow.Os using 4 Cores
# 	Time taken 1.5643 sec
# Running ./slow.Os using 5 Cores
# 	Time taken 1.1942 sec
# Running ./slow.Os using 6 Cores
# 	Time taken 1.6724 sec
# Running ./slow.Os using 7 Cores
# 	Time taken 1.6936 sec
# Running ./slow.Os using 8 Cores
# 	Time taken 1.6907 sec
# Running ./slow.Os using 9 Cores
# 	Time taken 1.8342 sec
# Running ./slow.Os using 10 Cores
# 	Time taken 1.8642 sec
# Running ./slow.Os using 11 Cores
# 	Time taken 2.2192 sec
# Running ./slow.Os using 12 Cores
# 	Time taken 2.0164 sec
# Running ./fast.O0 using 1 Cores
# 	Time taken 0.1694 sec
# Running ./fast.O0 using 2 Cores
# 	Time taken 0.0721 sec
# Running ./fast.O0 using 3 Cores
# 	Time taken 0.0498 sec
# Running ./fast.O0 using 4 Cores
# 	Time taken 0.0373 sec
# Running ./fast.O0 using 5 Cores
# 	Time taken 0.0358 sec
# Running ./fast.O0 using 6 Cores
# 	Time taken 0.0296 sec
# Running ./fast.O0 using 7 Cores
# 	Time taken 0.0261 sec
# Running ./fast.O0 using 8 Cores
# 	Time taken 0.0234 sec
# Running ./fast.O0 using 9 Cores
# 	Time taken 0.0299 sec
# Running ./fast.O0 using 10 Cores
# 	Time taken 0.0279 sec
# Running ./fast.O0 using 11 Cores
# 	Time taken 0.0297 sec
# Running ./fast.O0 using 12 Cores
# 	Time taken 0.0287 sec
# Running ./fast.O1 using 1 Cores
# 	Time taken 0.0469 sec
# Running ./fast.O1 using 2 Cores
# 	Time taken 0.0126 sec
# Running ./fast.O1 using 3 Cores
# 	Time taken 0.0076 sec
# Running ./fast.O1 using 4 Cores
# 	Time taken 0.0057 sec
# Running ./fast.O1 using 5 Cores
# 	Time taken 0.0060 sec
# Running ./fast.O1 using 6 Cores
# 	Time taken 0.0055 sec
# Running ./fast.O1 using 7 Cores
# 	Time taken 0.0050 sec
# Running ./fast.O1 using 8 Cores
# 	Time taken 0.0051 sec
# Running ./fast.O1 using 9 Cores
# 	Time taken 0.0051 sec
# Running ./fast.O1 using 10 Cores
# 	Time taken 0.0046 sec
# Running ./fast.O1 using 11 Cores
# 	Time taken 0.0044 sec
# Running ./fast.O1 using 12 Cores
# 	Time taken 0.0040 sec
# Running ./fast.O2 using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.O2 using 2 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 8 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 9 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.O3 using 2 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Ofast using 2 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 6 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Os using 2 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 12 Cores
# 	Time taken 0.0002 sec
# Running ./medium.O0 using 1 Cores
# 	Time taken 0.1599 sec
# Running ./medium.O0 using 2 Cores
# 	Time taken 0.3646 sec
# Running ./medium.O0 using 3 Cores
# 	Time taken 0.3748 sec
# Running ./medium.O0 using 4 Cores
# 	Time taken 0.4516 sec
# Running ./medium.O0 using 5 Cores
# 	Time taken 0.8167 sec
# Running ./medium.O0 using 6 Cores
# 	Time taken 0.7968 sec
# Running ./medium.O0 using 7 Cores
# 	Time taken 0.8054 sec
# Running ./medium.O0 using 8 Cores
# 	Time taken 0.8591 sec
# Running ./medium.O0 using 9 Cores
# 	Time taken 0.8739 sec
# Running ./medium.O0 using 10 Cores
# 	Time taken 0.8671 sec
# Running ./medium.O0 using 11 Cores
# 	Time taken 0.8455 sec
# Running ./medium.O0 using 12 Cores
# 	Time taken 0.8382 sec
# Running ./medium.O1 using 1 Cores
# 	Time taken 0.1748 sec
# Running ./medium.O1 using 2 Cores
# 	Time taken 0.2905 sec
# Running ./medium.O1 using 3 Cores
# 	Time taken 0.3410 sec
# Running ./medium.O1 using 4 Cores
# 	Time taken 0.3623 sec
# Running ./medium.O1 using 5 Cores
# 	Time taken 0.7788 sec
# Running ./medium.O1 using 6 Cores
# 	Time taken 0.8596 sec
# Running ./medium.O1 using 7 Cores
# 	Time taken 0.7138 sec
# Running ./medium.O1 using 8 Cores
# 	Time taken 0.6265 sec
# Running ./medium.O1 using 9 Cores
# 	Time taken 0.8521 sec
# Running ./medium.O1 using 10 Cores
# 	Time taken 0.7712 sec
# Running ./medium.O1 using 11 Cores
# 	Time taken 0.8709 sec
# Running ./medium.O1 using 12 Cores
# 	Time taken 0.9129 sec
# Running ./medium.O2 using 1 Cores
# 	Time taken 0.1757 sec
# Running ./medium.O2 using 2 Cores
# 	Time taken 0.2725 sec
# Running ./medium.O2 using 3 Cores
# 	Time taken 0.3427 sec
# Running ./medium.O2 using 4 Cores
# 	Time taken 0.3612 sec
# Running ./medium.O2 using 5 Cores
# 	Time taken 0.7639 sec
# Running ./medium.O2 using 6 Cores
# 	Time taken 0.8351 sec
# Running ./medium.O2 using 7 Cores
# 	Time taken 0.7457 sec
# Running ./medium.O2 using 8 Cores
# 	Time taken 0.7243 sec
# Running ./medium.O2 using 9 Cores
# 	Time taken 0.8210 sec
# Running ./medium.O2 using 10 Cores
# 	Time taken 0.7731 sec
# Running ./medium.O2 using 11 Cores
# 	Time taken 0.7890 sec
# Running ./medium.O2 using 12 Cores
# 	Time taken 0.8223 sec
# Running ./medium.O3 using 1 Cores
# 	Time taken 0.1798 sec
# Running ./medium.O3 using 2 Cores
# 	Time taken 0.2756 sec
# Running ./medium.O3 using 3 Cores
# 	Time taken 0.3311 sec
# Running ./medium.O3 using 4 Cores
# 	Time taken 0.3195 sec
# Running ./medium.O3 using 5 Cores
# 	Time taken 0.6493 sec
# Running ./medium.O3 using 6 Cores
# 	Time taken 0.8478 sec
# Running ./medium.O3 using 7 Cores
# 	Time taken 0.7173 sec
# Running ./medium.O3 using 8 Cores
# 	Time taken 0.8592 sec
# Running ./medium.O3 using 9 Cores
# 	Time taken 0.8175 sec
# Running ./medium.O3 using 10 Cores
# 	Time taken 0.8782 sec
# Running ./medium.O3 using 11 Cores
# 	Time taken 0.8281 sec
# Running ./medium.O3 using 12 Cores
# 	Time taken 0.8041 sec
# Running ./medium.Ofast using 1 Cores
# 	Time taken 0.1724 sec
# Running ./medium.Ofast using 2 Cores
# 	Time taken 0.2727 sec
# Running ./medium.Ofast using 3 Cores
# 	Time taken 0.3424 sec
# Running ./medium.Ofast using 4 Cores
# 	Time taken 0.3464 sec
# Running ./medium.Ofast using 5 Cores
# 	Time taken 0.6680 sec
# Running ./medium.Ofast using 6 Cores
# 	Time taken 0.7619 sec
# Running ./medium.Ofast using 7 Cores
# 	Time taken 0.7335 sec
# Running ./medium.Ofast using 8 Cores
# 	Time taken 0.7052 sec
# Running ./medium.Ofast using 9 Cores
# 	Time taken 0.7955 sec
# Running ./medium.Ofast using 10 Cores
# 	Time taken 0.8603 sec
# Running ./medium.Ofast using 11 Cores
# 	Time taken 0.8311 sec
# Running ./medium.Ofast using 12 Cores
# 	Time taken 0.8313 sec
# Running ./medium.Os using 1 Cores
# 	Time taken 0.1719 sec
# Running ./medium.Os using 2 Cores
# 	Time taken 0.2883 sec
# Running ./medium.Os using 3 Cores
# 	Time taken 0.3528 sec
# Running ./medium.Os using 4 Cores
# 	Time taken 0.3727 sec
# Running ./medium.Os using 5 Cores
# 	Time taken 0.6928 sec
# Running ./medium.Os using 6 Cores
# 	Time taken 0.8455 sec
# Running ./medium.Os using 7 Cores
# 	Time taken 0.7287 sec
# Running ./medium.Os using 8 Cores
# 	Time taken 0.7815 sec
# Running ./medium.Os using 9 Cores
# 	Time taken 0.8289 sec
# Running ./medium.Os using 10 Cores
# 	Time taken 0.9084 sec
# Running ./medium.Os using 11 Cores
# 	Time taken 0.6834 sec
# Running ./medium.Os using 12 Cores
# 	Time taken 0.8596 sec
#   Run  FileName    Optimization Level      Number of Threads  Time
# -----  ----------  --------------------  -------------------  ----------
#     1  slow.c      -O0                                     1  0.6053 sec
#     1  slow.c      -O0                                     2  1.1361 sec
#     1  slow.c      -O0                                     3  6.1665 sec
#     1  slow.c      -O0                                     4  1.7311 sec
#     1  slow.c      -O0                                     5  1.2980 sec
#     1  slow.c      -O0                                     6  1.7094 sec
#     1  slow.c      -O0                                     7  1.7056 sec
#     1  slow.c      -O0                                     8  1.7099 sec
#     1  slow.c      -O0                                     9  1.8539 sec
#     1  slow.c      -O0                                    10  2.1174 sec
#     1  slow.c      -O0                                    11  2.0872 sec
#     1  slow.c      -O0                                    12  2.0776 sec
#     1  slow.c      -O1                                     1  0.6139 sec
#     1  slow.c      -O1                                     2  1.3491 sec
#     1  slow.c      -O1                                     3  6.7334 sec
#     1  slow.c      -O1                                     4  1.6873 sec
#     1  slow.c      -O1                                     5  1.1151 sec
#     1  slow.c      -O1                                     6  1.6998 sec
#     1  slow.c      -O1                                     7  1.7006 sec
#     1  slow.c      -O1                                     8  1.7066 sec
#     1  slow.c      -O1                                     9  1.8621 sec
#     1  slow.c      -O1                                    10  2.2224 sec
#     1  slow.c      -O1                                    11  2.2507 sec
#     1  slow.c      -O1                                    12  2.1044 sec
#     1  slow.c      -O2                                     1  0.6129 sec
#     1  slow.c      -O2                                     2  1.0909 sec
#     1  slow.c      -O2                                     3  5.6812 sec
#     1  slow.c      -O2                                     4  1.5853 sec
#     1  slow.c      -O2                                     5  1.2907 sec
#     1  slow.c      -O2                                     6  1.7649 sec
#     1  slow.c      -O2                                     7  1.7719 sec
#     1  slow.c      -O2                                     8  1.8544 sec
#     1  slow.c      -O2                                     9  1.7731 sec
#     1  slow.c      -O2                                    10  2.1632 sec
#     1  slow.c      -O2                                    11  2.0082 sec
#     1  slow.c      -O2                                    12  2.2449 sec
#     1  slow.c      -O3                                     1  0.6125 sec
#     1  slow.c      -O3                                     2  1.1638 sec
#     1  slow.c      -O3                                     3  6.9850 sec
#     1  slow.c      -O3                                     4  1.7309 sec
#     1  slow.c      -O3                                     5  1.1103 sec
#     1  slow.c      -O3                                     6  1.7207 sec
#     1  slow.c      -O3                                     7  1.9970 sec
#     1  slow.c      -O3                                     8  1.7367 sec
#     1  slow.c      -O3                                     9  1.8425 sec
#     1  slow.c      -O3                                    10  2.0514 sec
#     1  slow.c      -O3                                    11  2.1148 sec
#     1  slow.c      -O3                                    12  2.1018 sec
#     1  slow.c      -Ofast                                  1  0.6169 sec
#     1  slow.c      -Ofast                                  2  1.0224 sec
#     1  slow.c      -Ofast                                  3  7.0828 sec
#     1  slow.c      -Ofast                                  4  1.6084 sec
#     1  slow.c      -Ofast                                  5  1.1571 sec
#     1  slow.c      -Ofast                                  6  1.6790 sec
#     1  slow.c      -Ofast                                  7  1.9686 sec
#     1  slow.c      -Ofast                                  8  1.7292 sec
#     1  slow.c      -Ofast                                  9  1.9724 sec
#     1  slow.c      -Ofast                                 10  2.1656 sec
#     1  slow.c      -Ofast                                 11  2.1030 sec
#     1  slow.c      -Ofast                                 12  2.3081 sec
#     1  slow.c      -Os                                     1  0.6180 sec
#     1  slow.c      -Os                                     2  1.0190 sec
#     1  slow.c      -Os                                     3  6.6465 sec
#     1  slow.c      -Os                                     4  1.5643 sec
#     1  slow.c      -Os                                     5  1.1942 sec
#     1  slow.c      -Os                                     6  1.6724 sec
#     1  slow.c      -Os                                     7  1.6936 sec
#     1  slow.c      -Os                                     8  1.6907 sec
#     1  slow.c      -Os                                     9  1.8342 sec
#     1  slow.c      -Os                                    10  1.8642 sec
#     1  slow.c      -Os                                    11  2.2192 sec
#     1  slow.c      -Os                                    12  2.0164 sec
#     1  fast.c      -O0                                     1  0.1694 sec
#     1  fast.c      -O0                                     2  0.0721 sec
#     1  fast.c      -O0                                     3  0.0498 sec
#     1  fast.c      -O0                                     4  0.0373 sec
#     1  fast.c      -O0                                     5  0.0358 sec
#     1  fast.c      -O0                                     6  0.0296 sec
#     1  fast.c      -O0                                     7  0.0261 sec
#     1  fast.c      -O0                                     8  0.0234 sec
#     1  fast.c      -O0                                     9  0.0299 sec
#     1  fast.c      -O0                                    10  0.0279 sec
#     1  fast.c      -O0                                    11  0.0297 sec
#     1  fast.c      -O0                                    12  0.0287 sec
#     1  fast.c      -O1                                     1  0.0469 sec
#     1  fast.c      -O1                                     2  0.0126 sec
#     1  fast.c      -O1                                     3  0.0076 sec
#     1  fast.c      -O1                                     4  0.0057 sec
#     1  fast.c      -O1                                     5  0.0060 sec
#     1  fast.c      -O1                                     6  0.0055 sec
#     1  fast.c      -O1                                     7  0.0050 sec
#     1  fast.c      -O1                                     8  0.0051 sec
#     1  fast.c      -O1                                     9  0.0051 sec
#     1  fast.c      -O1                                    10  0.0046 sec
#     1  fast.c      -O1                                    11  0.0044 sec
#     1  fast.c      -O1                                    12  0.0040 sec
#     1  fast.c      -O2                                     1  0.0000 sec
#     1  fast.c      -O2                                     2  0.0001 sec
#     1  fast.c      -O2                                     3  0.0001 sec
#     1  fast.c      -O2                                     4  0.0001 sec
#     1  fast.c      -O2                                     5  0.0001 sec
#     1  fast.c      -O2                                     6  0.0001 sec
#     1  fast.c      -O2                                     7  0.0001 sec
#     1  fast.c      -O2                                     8  0.0002 sec
#     1  fast.c      -O2                                     9  0.0001 sec
#     1  fast.c      -O2                                    10  0.0002 sec
#     1  fast.c      -O2                                    11  0.0002 sec
#     1  fast.c      -O2                                    12  0.0002 sec
#     1  fast.c      -O3                                     1  0.0000 sec
#     1  fast.c      -O3                                     2  0.0001 sec
#     1  fast.c      -O3                                     3  0.0001 sec
#     1  fast.c      -O3                                     4  0.0001 sec
#     1  fast.c      -O3                                     5  0.0001 sec
#     1  fast.c      -O3                                     6  0.0001 sec
#     1  fast.c      -O3                                     7  0.0001 sec
#     1  fast.c      -O3                                     8  0.0001 sec
#     1  fast.c      -O3                                     9  0.0002 sec
#     1  fast.c      -O3                                    10  0.0002 sec
#     1  fast.c      -O3                                    11  0.0002 sec
#     1  fast.c      -O3                                    12  0.0002 sec
#     1  fast.c      -Ofast                                  1  0.0000 sec
#     1  fast.c      -Ofast                                  2  0.0001 sec
#     1  fast.c      -Ofast                                  3  0.0001 sec
#     1  fast.c      -Ofast                                  4  0.0001 sec
#     1  fast.c      -Ofast                                  5  0.0001 sec
#     1  fast.c      -Ofast                                  6  0.0002 sec
#     1  fast.c      -Ofast                                  7  0.0001 sec
#     1  fast.c      -Ofast                                  8  0.0001 sec
#     1  fast.c      -Ofast                                  9  0.0002 sec
#     1  fast.c      -Ofast                                 10  0.0002 sec
#     1  fast.c      -Ofast                                 11  0.0002 sec
#     1  fast.c      -Ofast                                 12  0.0002 sec
#     1  fast.c      -Os                                     1  0.0000 sec
#     1  fast.c      -Os                                     2  0.0001 sec
#     1  fast.c      -Os                                     3  0.0001 sec
#     1  fast.c      -Os                                     4  0.0001 sec
#     1  fast.c      -Os                                     5  0.0001 sec
#     1  fast.c      -Os                                     6  0.0001 sec
#     1  fast.c      -Os                                     7  0.0001 sec
#     1  fast.c      -Os                                     8  0.0001 sec
#     1  fast.c      -Os                                     9  0.0002 sec
#     1  fast.c      -Os                                    10  0.0002 sec
#     1  fast.c      -Os                                    11  0.0002 sec
#     1  fast.c      -Os                                    12  0.0002 sec
#     1  medium.c    -O0                                     1  0.1599 sec
#     1  medium.c    -O0                                     2  0.3646 sec
#     1  medium.c    -O0                                     3  0.3748 sec
#     1  medium.c    -O0                                     4  0.4516 sec
#     1  medium.c    -O0                                     5  0.8167 sec
#     1  medium.c    -O0                                     6  0.7968 sec
#     1  medium.c    -O0                                     7  0.8054 sec
#     1  medium.c    -O0                                     8  0.8591 sec
#     1  medium.c    -O0                                     9  0.8739 sec
#     1  medium.c    -O0                                    10  0.8671 sec
#     1  medium.c    -O0                                    11  0.8455 sec
#     1  medium.c    -O0                                    12  0.8382 sec
#     1  medium.c    -O1                                     1  0.1748 sec
#     1  medium.c    -O1                                     2  0.2905 sec
#     1  medium.c    -O1                                     3  0.3410 sec
#     1  medium.c    -O1                                     4  0.3623 sec
#     1  medium.c    -O1                                     5  0.7788 sec
#     1  medium.c    -O1                                     6  0.8596 sec
#     1  medium.c    -O1                                     7  0.7138 sec
#     1  medium.c    -O1                                     8  0.6265 sec
#     1  medium.c    -O1                                     9  0.8521 sec
#     1  medium.c    -O1                                    10  0.7712 sec
#     1  medium.c    -O1                                    11  0.8709 sec
#     1  medium.c    -O1                                    12  0.9129 sec
#     1  medium.c    -O2                                     1  0.1757 sec
#     1  medium.c    -O2                                     2  0.2725 sec
#     1  medium.c    -O2                                     3  0.3427 sec
#     1  medium.c    -O2                                     4  0.3612 sec
#     1  medium.c    -O2                                     5  0.7639 sec
#     1  medium.c    -O2                                     6  0.8351 sec
#     1  medium.c    -O2                                     7  0.7457 sec
#     1  medium.c    -O2                                     8  0.7243 sec
#     1  medium.c    -O2                                     9  0.8210 sec
#     1  medium.c    -O2                                    10  0.7731 sec
#     1  medium.c    -O2                                    11  0.7890 sec
#     1  medium.c    -O2                                    12  0.8223 sec
#     1  medium.c    -O3                                     1  0.1798 sec
#     1  medium.c    -O3                                     2  0.2756 sec
#     1  medium.c    -O3                                     3  0.3311 sec
#     1  medium.c    -O3                                     4  0.3195 sec
#     1  medium.c    -O3                                     5  0.6493 sec
#     1  medium.c    -O3                                     6  0.8478 sec
#     1  medium.c    -O3                                     7  0.7173 sec
#     1  medium.c    -O3                                     8  0.8592 sec
#     1  medium.c    -O3                                     9  0.8175 sec
#     1  medium.c    -O3                                    10  0.8782 sec
#     1  medium.c    -O3                                    11  0.8281 sec
#     1  medium.c    -O3                                    12  0.8041 sec
#     1  medium.c    -Ofast                                  1  0.1724 sec
#     1  medium.c    -Ofast                                  2  0.2727 sec
#     1  medium.c    -Ofast                                  3  0.3424 sec
#     1  medium.c    -Ofast                                  4  0.3464 sec
#     1  medium.c    -Ofast                                  5  0.6680 sec
#     1  medium.c    -Ofast                                  6  0.7619 sec
#     1  medium.c    -Ofast                                  7  0.7335 sec
#     1  medium.c    -Ofast                                  8  0.7052 sec
#     1  medium.c    -Ofast                                  9  0.7955 sec
#     1  medium.c    -Ofast                                 10  0.8603 sec
#     1  medium.c    -Ofast                                 11  0.8311 sec
#     1  medium.c    -Ofast                                 12  0.8313 sec
#     1  medium.c    -Os                                     1  0.1719 sec
#     1  medium.c    -Os                                     2  0.2883 sec
#     1  medium.c    -Os                                     3  0.3528 sec
#     1  medium.c    -Os                                     4  0.3727 sec
#     1  medium.c    -Os                                     5  0.6928 sec
#     1  medium.c    -Os                                     6  0.8455 sec
#     1  medium.c    -Os                                     7  0.7287 sec
#     1  medium.c    -Os                                     8  0.7815 sec
#     1  medium.c    -Os                                     9  0.8289 sec
#     1  medium.c    -Os                                    10  0.9084 sec
#     1  medium.c    -Os                                    11  0.6834 sec
#     1  medium.c    -Os                                    12  0.8596 sec
# Starting Run 2
# Compiling slow.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Compiling fast.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Compiling medium.c
# 	Using Optimization Level: -O0
# 	Using Optimization Level: -O1
# 	Using Optimization Level: -O2
# 	Using Optimization Level: -O3
# 	Using Optimization Level: -Ofast
# 	Using Optimization Level: -Os
# Running ./slow.O0 using 1 Cores
# 	Time taken 0.5901 sec
# Running ./slow.O0 using 2 Cores
# 	Time taken 0.9714 sec
# Running ./slow.O0 using 3 Cores
# 	Time taken 4.6309 sec
# Running ./slow.O0 using 4 Cores
# 	Time taken 1.7963 sec
# Running ./slow.O0 using 5 Cores
# 	Time taken 1.1875 sec
# Running ./slow.O0 using 6 Cores
# 	Time taken 1.7276 sec
# Running ./slow.O0 using 7 Cores
# 	Time taken 1.6641 sec
# Running ./slow.O0 using 8 Cores
# 	Time taken 1.7583 sec
# Running ./slow.O0 using 9 Cores
# 	Time taken 1.6439 sec
# Running ./slow.O0 using 10 Cores
# 	Time taken 1.7985 sec
# Running ./slow.O0 using 11 Cores
# 	Time taken 1.8590 sec
# Running ./slow.O0 using 12 Cores
# 	Time taken 2.1186 sec
# Running ./slow.O1 using 1 Cores
# 	Time taken 0.5917 sec
# Running ./slow.O1 using 2 Cores
# 	Time taken 1.1519 sec
# Running ./slow.O1 using 3 Cores
# 	Time taken 8.3415 sec
# Running ./slow.O1 using 4 Cores
# 	Time taken 1.8641 sec
# Running ./slow.O1 using 5 Cores
# 	Time taken 1.2074 sec
# Running ./slow.O1 using 6 Cores
# 	Time taken 1.6840 sec
# Running ./slow.O1 using 7 Cores
# 	Time taken 1.6837 sec
# Running ./slow.O1 using 8 Cores
# 	Time taken 1.7271 sec
# Running ./slow.O1 using 9 Cores
# 	Time taken 1.5197 sec
# Running ./slow.O1 using 10 Cores
# 	Time taken 1.5323 sec
# Running ./slow.O1 using 11 Cores
# 	Time taken 1.9567 sec
# Running ./slow.O1 using 12 Cores
# 	Time taken 2.3488 sec
# Running ./slow.O2 using 1 Cores
# 	Time taken 0.5873 sec
# Running ./slow.O2 using 2 Cores
# 	Time taken 1.1783 sec
# Running ./slow.O2 using 3 Cores
# 	Time taken 7.6094 sec
# Running ./slow.O2 using 4 Cores
# 	Time taken 2.0270 sec
# Running ./slow.O2 using 5 Cores
# 	Time taken 1.1649 sec
# Running ./slow.O2 using 6 Cores
# 	Time taken 1.6544 sec
# Running ./slow.O2 using 7 Cores
# 	Time taken 1.6958 sec
# Running ./slow.O2 using 8 Cores
# 	Time taken 1.6970 sec
# Running ./slow.O2 using 9 Cores
# 	Time taken 1.7815 sec
# Running ./slow.O2 using 10 Cores
# 	Time taken 2.1709 sec
# Running ./slow.O2 using 11 Cores
# 	Time taken 2.0418 sec
# Running ./slow.O2 using 12 Cores
# 	Time taken 2.0208 sec
# Running ./slow.O3 using 1 Cores
# 	Time taken 0.6019 sec
# Running ./slow.O3 using 2 Cores
# 	Time taken 1.0481 sec
# Running ./slow.O3 using 3 Cores
# 	Time taken 6.2705 sec
# Running ./slow.O3 using 4 Cores
# 	Time taken 1.8900 sec
# Running ./slow.O3 using 5 Cores
# 	Time taken 1.2804 sec
# Running ./slow.O3 using 6 Cores
# 	Time taken 1.7101 sec
# Running ./slow.O3 using 7 Cores
# 	Time taken 1.7185 sec
# Running ./slow.O3 using 8 Cores
# 	Time taken 1.7194 sec
# Running ./slow.O3 using 9 Cores
# 	Time taken 1.7078 sec
# Running ./slow.O3 using 10 Cores
# 	Time taken 1.7657 sec
# Running ./slow.O3 using 11 Cores
# 	Time taken 1.7888 sec
# Running ./slow.O3 using 12 Cores
# 	Time taken 1.9363 sec
# Running ./slow.Ofast using 1 Cores
# 	Time taken 0.6019 sec
# Running ./slow.Ofast using 2 Cores
# 	Time taken 1.0996 sec
# Running ./slow.Ofast using 3 Cores
# 	Time taken 6.1692 sec
# Running ./slow.Ofast using 4 Cores
# 	Time taken 1.8250 sec
# Running ./slow.Ofast using 5 Cores
# 	Time taken 1.3658 sec
# Running ./slow.Ofast using 6 Cores
# 	Time taken 1.7001 sec
# Running ./slow.Ofast using 7 Cores
# 	Time taken 1.7124 sec
# Running ./slow.Ofast using 8 Cores
# 	Time taken 1.7671 sec
# Running ./slow.Ofast using 9 Cores
# 	Time taken 1.7112 sec
# Running ./slow.Ofast using 10 Cores
# 	Time taken 2.0276 sec
# Running ./slow.Ofast using 11 Cores
# 	Time taken 1.9337 sec
# Running ./slow.Ofast using 12 Cores
# 	Time taken 1.8630 sec
# Running ./slow.Os using 1 Cores
# 	Time taken 0.5975 sec
# Running ./slow.Os using 2 Cores
# 	Time taken 1.2606 sec
# Running ./slow.Os using 3 Cores
# 	Time taken 6.4311 sec
# Running ./slow.Os using 4 Cores
# 	Time taken 1.8706 sec
# Running ./slow.Os using 5 Cores
# 	Time taken 1.3604 sec
# Running ./slow.Os using 6 Cores
# 	Time taken 1.7421 sec
# Running ./slow.Os using 7 Cores
# 	Time taken 1.7385 sec
# Running ./slow.Os using 8 Cores
# 	Time taken 1.7494 sec
# Running ./slow.Os using 9 Cores
# 	Time taken 1.7506 sec
# Running ./slow.Os using 10 Cores
# 	Time taken 1.7683 sec
# Running ./slow.Os using 11 Cores
# 	Time taken 1.7646 sec
# Running ./slow.Os using 12 Cores
# 	Time taken 2.1521 sec
# Running ./fast.O0 using 1 Cores
# 	Time taken 0.1448 sec
# Running ./fast.O0 using 2 Cores
# 	Time taken 0.0730 sec
# Running ./fast.O0 using 3 Cores
# 	Time taken 0.0502 sec
# Running ./fast.O0 using 4 Cores
# 	Time taken 0.0385 sec
# Running ./fast.O0 using 5 Cores
# 	Time taken 0.0361 sec
# Running ./fast.O0 using 6 Cores
# 	Time taken 0.0299 sec
# Running ./fast.O0 using 7 Cores
# 	Time taken 0.0387 sec
# Running ./fast.O0 using 8 Cores
# 	Time taken 0.0384 sec
# Running ./fast.O0 using 9 Cores
# 	Time taken 0.0315 sec
# Running ./fast.O0 using 10 Cores
# 	Time taken 0.0301 sec
# Running ./fast.O0 using 11 Cores
# 	Time taken 0.0304 sec
# Running ./fast.O0 using 12 Cores
# 	Time taken 0.0266 sec
# Running ./fast.O1 using 1 Cores
# 	Time taken 0.0285 sec
# Running ./fast.O1 using 2 Cores
# 	Time taken 0.0115 sec
# Running ./fast.O1 using 3 Cores
# 	Time taken 0.0088 sec
# Running ./fast.O1 using 4 Cores
# 	Time taken 0.0068 sec
# Running ./fast.O1 using 5 Cores
# 	Time taken 0.0069 sec
# Running ./fast.O1 using 6 Cores
# 	Time taken 0.0054 sec
# Running ./fast.O1 using 7 Cores
# 	Time taken 0.0052 sec
# Running ./fast.O1 using 8 Cores
# 	Time taken 0.0057 sec
# Running ./fast.O1 using 9 Cores
# 	Time taken 0.0058 sec
# Running ./fast.O1 using 10 Cores
# 	Time taken 0.0053 sec
# Running ./fast.O1 using 11 Cores
# 	Time taken 0.0055 sec
# Running ./fast.O1 using 12 Cores
# 	Time taken 0.0048 sec
# Running ./fast.O2 using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.O2 using 2 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O2 using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O2 using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.O3 using 2 Cores
# 	Time taken 0.0000 sec
# Running ./fast.O3 using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 6 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 7 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 9 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 10 Cores
# 	Time taken 0.0001 sec
# Running ./fast.O3 using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.O3 using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Ofast using 2 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Ofast using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Ofast using 8 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 10 Cores
# 	Time taken 0.0003 sec
# Running ./fast.Ofast using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Ofast using 12 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 1 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Os using 2 Cores
# 	Time taken 0.0000 sec
# Running ./fast.Os using 3 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 4 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 5 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 6 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 7 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 8 Cores
# 	Time taken 0.0001 sec
# Running ./fast.Os using 9 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 10 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 11 Cores
# 	Time taken 0.0002 sec
# Running ./fast.Os using 12 Cores
# 	Time taken 0.0002 sec
# Running ./medium.O0 using 1 Cores
# 	Time taken 0.1693 sec
# Running ./medium.O0 using 2 Cores
# 	Time taken 0.3635 sec
# Running ./medium.O0 using 3 Cores
# 	Time taken 0.4026 sec
# Running ./medium.O0 using 4 Cores
# 	Time taken 0.4961 sec
# Running ./medium.O0 using 5 Cores
# 	Time taken 0.8362 sec
# Running ./medium.O0 using 6 Cores
# 	Time taken 0.8083 sec
# Running ./medium.O0 using 7 Cores
# 	Time taken 0.8109 sec
# Running ./medium.O0 using 8 Cores
# 	Time taken 0.8558 sec
# Running ./medium.O0 using 9 Cores
# 	Time taken 0.8736 sec
# Running ./medium.O0 using 10 Cores
# 	Time taken 0.9547 sec
# Running ./medium.O0 using 11 Cores
# 	Time taken 0.9416 sec
# Running ./medium.O0 using 12 Cores
# 	Time taken 0.9575 sec
# Running ./medium.O1 using 1 Cores
# 	Time taken 0.1586 sec
# Running ./medium.O1 using 2 Cores
# 	Time taken 0.2811 sec
# Running ./medium.O1 using 3 Cores
# 	Time taken 0.3341 sec
# Running ./medium.O1 using 4 Cores
# 	Time taken 0.3597 sec
# Running ./medium.O1 using 5 Cores
# 	Time taken 0.6190 sec
# Running ./medium.O1 using 6 Cores
# 	Time taken 0.7297 sec
# Running ./medium.O1 using 7 Cores
# 	Time taken 0.7521 sec
# Running ./medium.O1 using 8 Cores
# 	Time taken 0.8226 sec
# Running ./medium.O1 using 9 Cores
# 	Time taken 0.7929 sec
# Running ./medium.O1 using 10 Cores
# 	Time taken 0.7500 sec
# Running ./medium.O1 using 11 Cores
# 	Time taken 0.7601 sec
# Running ./medium.O1 using 12 Cores
# 	Time taken 0.7107 sec
# Running ./medium.O2 using 1 Cores
# 	Time taken 0.1642 sec
# Running ./medium.O2 using 2 Cores
# 	Time taken 0.2661 sec
# Running ./medium.O2 using 3 Cores
# 	Time taken 0.3395 sec
# Running ./medium.O2 using 4 Cores
# 	Time taken 0.3614 sec
# Running ./medium.O2 using 5 Cores
# 	Time taken 0.7173 sec
# Running ./medium.O2 using 6 Cores
# 	Time taken 0.7505 sec
# Running ./medium.O2 using 7 Cores
# 	Time taken 0.7175 sec
# Running ./medium.O2 using 8 Cores
# 	Time taken 0.8307 sec
# Running ./medium.O2 using 9 Cores
# 	Time taken 0.8700 sec
# Running ./medium.O2 using 10 Cores
# 	Time taken 0.8765 sec
# Running ./medium.O2 using 11 Cores
# 	Time taken 0.8323 sec
# Running ./medium.O2 using 12 Cores
# 	Time taken 0.8610 sec
# Running ./medium.O3 using 1 Cores
# 	Time taken 0.1707 sec
# Running ./medium.O3 using 2 Cores
# 	Time taken 0.2545 sec
# Running ./medium.O3 using 3 Cores
# 	Time taken 0.3344 sec
# Running ./medium.O3 using 4 Cores
# 	Time taken 0.3415 sec
# Running ./medium.O3 using 5 Cores
# 	Time taken 0.7688 sec
# Running ./medium.O3 using 6 Cores
# 	Time taken 0.7866 sec
# Running ./medium.O3 using 7 Cores
# 	Time taken 0.7640 sec
# Running ./medium.O3 using 8 Cores
# 	Time taken 0.8526 sec
# Running ./medium.O3 using 9 Cores
# 	Time taken 0.8238 sec
# Running ./medium.O3 using 10 Cores
# 	Time taken 0.8491 sec
# Running ./medium.O3 using 11 Cores
# 	Time taken 0.7544 sec
# Running ./medium.O3 using 12 Cores
# 	Time taken 0.7866 sec
# Running ./medium.Ofast using 1 Cores
# 	Time taken 0.1576 sec
# Running ./medium.Ofast using 2 Cores
# 	Time taken 0.2506 sec
# Running ./medium.Ofast using 3 Cores
# 	Time taken 0.3562 sec
# Running ./medium.Ofast using 4 Cores
# 	Time taken 0.3986 sec
# Running ./medium.Ofast using 5 Cores
# 	Time taken 0.6779 sec
# Running ./medium.Ofast using 6 Cores
# 	Time taken 0.7441 sec
# Running ./medium.Ofast using 7 Cores
# 	Time taken 0.7083 sec
# Running ./medium.Ofast using 8 Cores
# 	Time taken 0.8172 sec
# Running ./medium.Ofast using 9 Cores
# 	Time taken 0.8129 sec
# Running ./medium.Ofast using 10 Cores
# 	Time taken 0.8108 sec
# Running ./medium.Ofast using 11 Cores
# 	Time taken 0.8249 sec
# Running ./medium.Ofast using 12 Cores
# 	Time taken 0.7127 sec
# Running ./medium.Os using 1 Cores
# 	Time taken 0.1641 sec
# Running ./medium.Os using 2 Cores
# 	Time taken 0.2902 sec
# Running ./medium.Os using 3 Cores
# 	Time taken 0.3503 sec
# Running ./medium.Os using 4 Cores
# 	Time taken 0.3586 sec
# Running ./medium.Os using 5 Cores
# 	Time taken 0.7545 sec
# Running ./medium.Os using 6 Cores
# 	Time taken 0.8010 sec
# Running ./medium.Os using 7 Cores
# 	Time taken 0.7767 sec
# Running ./medium.Os using 8 Cores
# 	Time taken 0.8459 sec
# Running ./medium.Os using 9 Cores
# 	Time taken 0.8648 sec
# Running ./medium.Os using 10 Cores
# 	Time taken 0.8537 sec
# Running ./medium.Os using 11 Cores
# 	Time taken 0.8053 sec
# Running ./medium.Os using 12 Cores
# 	Time taken 0.8062 sec
#   Run  FileName    Optimization Level      Number of Threads  Time
# -----  ----------  --------------------  -------------------  ----------
#     2  slow.c      -O0                                     1  0.5901 sec
#     2  slow.c      -O0                                     2  0.9714 sec
#     2  slow.c      -O0                                     3  4.6309 sec
#     2  slow.c      -O0                                     4  1.7963 sec
#     2  slow.c      -O0                                     5  1.1875 sec
#     2  slow.c      -O0                                     6  1.7276 sec
#     2  slow.c      -O0                                     7  1.6641 sec
#     2  slow.c      -O0                                     8  1.7583 sec
#     2  slow.c      -O0                                     9  1.6439 sec
#     2  slow.c      -O0                                    10  1.7985 sec
#     2  slow.c      -O0                                    11  1.8590 sec
#     2  slow.c      -O0                                    12  2.1186 sec
#     2  slow.c      -O1                                     1  0.5917 sec
#     2  slow.c      -O1                                     2  1.1519 sec
#     2  slow.c      -O1                                     3  8.3415 sec
#     2  slow.c      -O1                                     4  1.8641 sec
#     2  slow.c      -O1                                     5  1.2074 sec
#     2  slow.c      -O1                                     6  1.6840 sec
#     2  slow.c      -O1                                     7  1.6837 sec
#     2  slow.c      -O1                                     8  1.7271 sec
#     2  slow.c      -O1                                     9  1.5197 sec
#     2  slow.c      -O1                                    10  1.5323 sec
#     2  slow.c      -O1                                    11  1.9567 sec
#     2  slow.c      -O1                                    12  2.3488 sec
#     2  slow.c      -O2                                     1  0.5873 sec
#     2  slow.c      -O2                                     2  1.1783 sec
#     2  slow.c      -O2                                     3  7.6094 sec
#     2  slow.c      -O2                                     4  2.0270 sec
#     2  slow.c      -O2                                     5  1.1649 sec
#     2  slow.c      -O2                                     6  1.6544 sec
#     2  slow.c      -O2                                     7  1.6958 sec
#     2  slow.c      -O2                                     8  1.6970 sec
#     2  slow.c      -O2                                     9  1.7815 sec
#     2  slow.c      -O2                                    10  2.1709 sec
#     2  slow.c      -O2                                    11  2.0418 sec
#     2  slow.c      -O2                                    12  2.0208 sec
#     2  slow.c      -O3                                     1  0.6019 sec
#     2  slow.c      -O3                                     2  1.0481 sec
#     2  slow.c      -O3                                     3  6.2705 sec
#     2  slow.c      -O3                                     4  1.8900 sec
#     2  slow.c      -O3                                     5  1.2804 sec
#     2  slow.c      -O3                                     6  1.7101 sec
#     2  slow.c      -O3                                     7  1.7185 sec
#     2  slow.c      -O3                                     8  1.7194 sec
#     2  slow.c      -O3                                     9  1.7078 sec
#     2  slow.c      -O3                                    10  1.7657 sec
#     2  slow.c      -O3                                    11  1.7888 sec
#     2  slow.c      -O3                                    12  1.9363 sec
#     2  slow.c      -Ofast                                  1  0.6019 sec
#     2  slow.c      -Ofast                                  2  1.0996 sec
#     2  slow.c      -Ofast                                  3  6.1692 sec
#     2  slow.c      -Ofast                                  4  1.8250 sec
#     2  slow.c      -Ofast                                  5  1.3658 sec
#     2  slow.c      -Ofast                                  6  1.7001 sec
#     2  slow.c      -Ofast                                  7  1.7124 sec
#     2  slow.c      -Ofast                                  8  1.7671 sec
#     2  slow.c      -Ofast                                  9  1.7112 sec
#     2  slow.c      -Ofast                                 10  2.0276 sec
#     2  slow.c      -Ofast                                 11  1.9337 sec
#     2  slow.c      -Ofast                                 12  1.8630 sec
#     2  slow.c      -Os                                     1  0.5975 sec
#     2  slow.c      -Os                                     2  1.2606 sec
#     2  slow.c      -Os                                     3  6.4311 sec
#     2  slow.c      -Os                                     4  1.8706 sec
#     2  slow.c      -Os                                     5  1.3604 sec
#     2  slow.c      -Os                                     6  1.7421 sec
#     2  slow.c      -Os                                     7  1.7385 sec
#     2  slow.c      -Os                                     8  1.7494 sec
#     2  slow.c      -Os                                     9  1.7506 sec
#     2  slow.c      -Os                                    10  1.7683 sec
#     2  slow.c      -Os                                    11  1.7646 sec
#     2  slow.c      -Os                                    12  2.1521 sec
#     2  fast.c      -O0                                     1  0.1448 sec
#     2  fast.c      -O0                                     2  0.0730 sec
#     2  fast.c      -O0                                     3  0.0502 sec
#     2  fast.c      -O0                                     4  0.0385 sec
#     2  fast.c      -O0                                     5  0.0361 sec
#     2  fast.c      -O0                                     6  0.0299 sec
#     2  fast.c      -O0                                     7  0.0387 sec
#     2  fast.c      -O0                                     8  0.0384 sec
#     2  fast.c      -O0                                     9  0.0315 sec
#     2  fast.c      -O0                                    10  0.0301 sec
#     2  fast.c      -O0                                    11  0.0304 sec
#     2  fast.c      -O0                                    12  0.0266 sec
#     2  fast.c      -O1                                     1  0.0285 sec
# ...
# 	Time taken 0.7158 sec
# Running ./medium.Os using 12 Cores
# 	Time taken 0.7285 sec
#   Run  FileName    Optimization Level      Number of Threads  Time
# -----  ----------  --------------------  -------------------  ----------
#     5  slow.c      -O0                                     1  0.6186 sec
#     5  slow.c      -O0                                     2  0.9451 sec
#     5  slow.c      -O0                                     3  5.2564 sec
#     5  slow.c      -O0                                     4  1.7057 sec
#     5  slow.c      -O0                                     5  1.4203 sec
#     5  slow.c      -O0                                     6  1.6854 sec
#     5  slow.c      -O0                                     7  1.6868 sec
#     5  slow.c      -O0                                     8  1.8883 sec
#     5  slow.c      -O0                                     9  1.9447 sec
#     5  slow.c      -O0                                    10  2.0134 sec
#     5  slow.c      -O0                                    11  1.8760 sec
#     5  slow.c      -O0                                    12  2.0025 sec
#     5  slow.c      -O1                                     1  0.6140 sec
#     5  slow.c      -O1                                     2  1.2539 sec
#     5  slow.c      -O1                                     3  5.2041 sec
#     5  slow.c      -O1                                     4  1.6365 sec
#     5  slow.c      -O1                                     5  1.2450 sec
#     5  slow.c      -O1                                     6  1.7140 sec
#     5  slow.c      -O1                                     7  1.8301 sec
#     5  slow.c      -O1                                     8  1.8428 sec
#     5  slow.c      -O1                                     9  1.8161 sec
#     5  slow.c      -O1                                    10  2.1263 sec
#     5  slow.c      -O1                                    11  2.0766 sec
#     5  slow.c      -O1                                    12  2.1310 sec
#     5  slow.c      -O2                                     1  0.6204 sec
#     5  slow.c      -O2                                     2  1.0358 sec
#     5  slow.c      -O2                                     3  6.0276 sec
#     5  slow.c      -O2                                     4  1.5016 sec
#     5  slow.c      -O2                                     5  1.2641 sec
#     5  slow.c      -O2                                     6  1.7153 sec
#     5  slow.c      -O2                                     7  1.7354 sec
#     5  slow.c      -O2                                     8  1.7612 sec
#     5  slow.c      -O2                                     9  1.8021 sec
#     5  slow.c      -O2                                    10  1.9096 sec
#     5  slow.c      -O2                                    11  2.0994 sec
#     5  slow.c      -O2                                    12  2.1331 sec
#     5  slow.c      -O3                                     1  0.6245 sec
#     5  slow.c      -O3                                     2  1.0650 sec
#     5  slow.c      -O3                                     3  5.1380 sec
#     5  slow.c      -O3                                     4  1.5998 sec
#     5  slow.c      -O3                                     5  1.2683 sec
#     5  slow.c      -O3                                     6  1.7118 sec
#     5  slow.c      -O3                                     7  1.6761 sec
#     5  slow.c      -O3                                     8  1.8589 sec
#     5  slow.c      -O3                                     9  2.0090 sec
#     5  slow.c      -O3                                    10  1.9097 sec
#     5  slow.c      -O3                                    11  2.0857 sec
#     5  slow.c      -O3                                    12  2.1270 sec
#     5  slow.c      -Ofast                                  1  0.6203 sec
#     5  slow.c      -Ofast                                  2  1.1635 sec
#     5  slow.c      -Ofast                                  3  5.6928 sec
#     5  slow.c      -Ofast                                  4  1.6181 sec
#     5  slow.c      -Ofast                                  5  1.2655 sec
#     5  slow.c      -Ofast                                  6  1.6835 sec
#     5  slow.c      -Ofast                                  7  1.7291 sec
#     5  slow.c      -Ofast                                  8  1.7832 sec
#     5  slow.c      -Ofast                                  9  1.8190 sec
#     5  slow.c      -Ofast                                 10  2.0014 sec
#     5  slow.c      -Ofast                                 11  1.9696 sec
#     5  slow.c      -Ofast                                 12  2.0994 sec
#     5  slow.c      -Os                                     1  0.6139 sec
#     5  slow.c      -Os                                     2  1.1355 sec
#     5  slow.c      -Os                                     3  5.9903 sec
#     5  slow.c      -Os                                     4  1.6580 sec
#     5  slow.c      -Os                                     5  1.2186 sec
#     5  slow.c      -Os                                     6  1.7036 sec
#     5  slow.c      -Os                                     7  1.7195 sec
#     5  slow.c      -Os                                     8  1.8230 sec
#     5  slow.c      -Os                                     9  1.9520 sec
#     5  slow.c      -Os                                    10  2.0818 sec
#     5  slow.c      -Os                                    11  1.9119 sec
#     5  slow.c      -Os                                    12  2.0678 sec
#     5  fast.c      -O0                                     1  0.1693 sec
#     5  fast.c      -O0                                     2  0.0725 sec
#     5  fast.c      -O0                                     3  0.0502 sec
#     5  fast.c      -O0                                     4  0.0375 sec
#     5  fast.c      -O0                                     5  0.0335 sec
#     5  fast.c      -O0                                     6  0.0392 sec
#     5  fast.c      -O0                                     7  0.0306 sec
#     5  fast.c      -O0                                     8  0.0256 sec
#     5  fast.c      -O0                                     9  0.0318 sec
#     5  fast.c      -O0                                    10  0.0287 sec
#     5  fast.c      -O0                                    11  0.0285 sec
#     5  fast.c      -O0                                    12  0.0329 sec
#     5  fast.c      -O1                                     1  0.0283 sec
#     5  fast.c      -O1                                     2  0.0117 sec
#     5  fast.c      -O1                                     3  0.0080 sec
#     5  fast.c      -O1                                     4  0.0057 sec
#     5  fast.c      -O1                                     5  0.0059 sec
#     5  fast.c      -O1                                     6  0.0054 sec
#     5  fast.c      -O1                                     7  0.0058 sec
#     5  fast.c      -O1                                     8  0.0050 sec
#     5  fast.c      -O1                                     9  0.0052 sec
#     5  fast.c      -O1                                    10  0.0054 sec
#     5  fast.c      -O1                                    11  0.0049 sec
#     5  fast.c      -O1                                    12  0.0048 sec
#     5  fast.c      -O2                                     1  0.0000 sec
#     5  fast.c      -O2                                     2  0.0000 sec
#     5  fast.c      -O2                                     3  0.0001 sec
#     5  fast.c      -O2                                     4  0.0001 sec
#     5  fast.c      -O2                                     5  0.0001 sec
#     5  fast.c      -O2                                     6  0.0001 sec
#     5  fast.c      -O2                                     7  0.0001 sec
#     5  fast.c      -O2                                     8  0.0001 sec
#     5  fast.c      -O2                                     9  0.0002 sec
#     5  fast.c      -O2                                    10  0.0002 sec
#     5  fast.c      -O2                                    11  0.0002 sec
#     5  fast.c      -O2                                    12  0.0002 sec
#     5  fast.c      -O3                                     1  0.0000 sec
#     5  fast.c      -O3                                     2  0.0000 sec
#     5  fast.c      -O3                                     3  0.0001 sec
#     5  fast.c      -O3                                     4  0.0000 sec
#     5  fast.c      -O3                                     5  0.0001 sec
#     5  fast.c      -O3                                     6  0.0001 sec
#     5  fast.c      -O3                                     7  0.0001 sec
#     5  fast.c      -O3                                     8  0.0001 sec
#     5  fast.c      -O3                                     9  0.0001 sec
#     5  fast.c      -O3                                    10  0.0001 sec
#     5  fast.c      -O3                                    11  0.0002 sec
#     5  fast.c      -O3                                    12  0.0002 sec
#     5  fast.c      -Ofast                                  1  0.0000 sec
#     5  fast.c      -Ofast                                  2  0.0000 sec
#     5  fast.c      -Ofast                                  3  0.0001 sec
#     5  fast.c      -Ofast                                  4  0.0001 sec
#     5  fast.c      -Ofast                                  5  0.0002 sec
#     5  fast.c      -Ofast                                  6  0.0002 sec
#     5  fast.c      -Ofast                                  7  0.0002 sec
#     5  fast.c      -Ofast                                  8  0.0004 sec
#     5  fast.c      -Ofast                                  9  0.0002 sec
#     5  fast.c      -Ofast                                 10  0.0002 sec
#     5  fast.c      -Ofast                                 11  0.0003 sec
#     5  fast.c      -Ofast                                 12  0.0003 sec
#     5  fast.c      -Os                                     1  0.0000 sec
#     5  fast.c      -Os                                     2  0.0000 sec
#     5  fast.c      -Os                                     3  0.0001 sec
#     5  fast.c      -Os                                     4  0.0001 sec
#     5  fast.c      -Os                                     5  0.0001 sec
#     5  fast.c      -Os                                     6  0.0002 sec
#     5  fast.c      -Os                                     7  0.0001 sec
#     5  fast.c      -Os                                     8  0.0001 sec
#     5  fast.c      -Os                                     9  0.0002 sec
#     5  fast.c      -Os                                    10  0.0002 sec
#     5  fast.c      -Os                                    11  0.0002 sec
#     5  fast.c      -Os                                    12  0.0002 sec
#     5  medium.c    -O0                                     1  0.1824 sec
#     5  medium.c    -O0                                     2  0.3402 sec
#     5  medium.c    -O0                                     3  0.3749 sec
#     5  medium.c    -O0                                     4  0.5086 sec
#     5  medium.c    -O0                                     5  0.7411 sec
#     5  medium.c    -O0                                     6  0.8155 sec
#     5  medium.c    -O0                                     7  0.7562 sec
#     5  medium.c    -O0                                     8  0.8257 sec
#     5  medium.c    -O0                                     9  0.8731 sec
#     5  medium.c    -O0                                    10  0.8028 sec
#     5  medium.c    -O0                                    11  0.8511 sec
#     5  medium.c    -O0                                    12  0.8300 sec
#     5  medium.c    -O1                                     1  0.1749 sec
#     5  medium.c    -O1                                     2  0.2646 sec
#     5  medium.c    -O1                                     3  0.3389 sec
#     5  medium.c    -O1                                     4  0.3698 sec
#     5  medium.c    -O1                                     5  0.7614 sec
#     5  medium.c    -O1                                     6  0.7746 sec
#     5  medium.c    -O1                                     7  0.6884 sec
#     5  medium.c    -O1                                     8  0.7524 sec
#     5  medium.c    -O1                                     9  0.8099 sec
#     5  medium.c    -O1                                    10  0.7640 sec
#     5  medium.c    -O1                                    11  0.7771 sec
#     5  medium.c    -O1                                    12  0.7811 sec
#     5  medium.c    -O2                                     1  0.1738 sec
#     5  medium.c    -O2                                     2  0.2535 sec
#     5  medium.c    -O2                                     3  0.3363 sec
#     5  medium.c    -O2                                     4  0.3769 sec
#     5  medium.c    -O2                                     5  0.6914 sec
#     5  medium.c    -O2                                     6  0.7998 sec
#     5  medium.c    -O2                                     7  0.7095 sec
#     5  medium.c    -O2                                     8  0.6973 sec
#     5  medium.c    -O2                                     9  0.7811 sec
#     5  medium.c    -O2                                    10  0.6873 sec
#     5  medium.c    -O2                                    11  0.7378 sec
#     5  medium.c    -O2                                    12  0.7370 sec
#     5  medium.c    -O3                                     1  0.1664 sec
#     5  medium.c    -O3                                     2  0.2597 sec
#     5  medium.c    -O3                                     3  0.3503 sec
#     5  medium.c    -O3                                     4  0.3830 sec
#     5  medium.c    -O3                                     5  0.7399 sec
#     5  medium.c    -O3                                     6  0.7542 sec
#     5  medium.c    -O3                                     7  0.7062 sec
#     5  medium.c    -O3                                     8  0.7100 sec
#     5  medium.c    -O3                                     9  0.7284 sec
#     5  medium.c    -O3                                    10  0.7778 sec
#     5  medium.c    -O3                                    11  0.7490 sec
#     5  medium.c    -O3                                    12  0.7021 sec
#     5  medium.c    -Ofast                                  1  0.1797 sec
#     5  medium.c    -Ofast                                  2  0.2725 sec
#     5  medium.c    -Ofast                                  3  0.3198 sec
#     5  medium.c    -Ofast                                  4  0.3673 sec
#     5  medium.c    -Ofast                                  5  0.6830 sec
#     5  medium.c    -Ofast                                  6  0.6627 sec
#     5  medium.c    -Ofast                                  7  0.7484 sec
#     5  medium.c    -Ofast                                  8  0.7521 sec
#     5  medium.c    -Ofast                                  9  0.7667 sec
#     5  medium.c    -Ofast                                 10  0.7605 sec
#     5  medium.c    -Ofast                                 11  0.7302 sec
#     5  medium.c    -Ofast                                 12  0.7706 sec
#     5  medium.c    -Os                                     1  0.1585 sec
#     5  medium.c    -Os                                     2  0.2931 sec
#     5  medium.c    -Os                                     3  0.3534 sec
#     5  medium.c    -Os                                     4  0.3848 sec
#     5  medium.c    -Os                                     5  0.6884 sec
#     5  medium.c    -Os                                     6  0.7663 sec
#     5  medium.c    -Os                                     7  0.6980 sec
#     5  medium.c    -Os                                     8  0.7265 sec
#     5  medium.c    -Os                                     9  0.7567 sec
#     5  medium.c    -Os                                    10  0.7551 sec
#     5  medium.c    -Os                                    11  0.7158 sec
#     5  medium.c    -Os                                    12  0.7285 sec

# %%
# Read the data from the file
file_path = 'execution_times.txt'
data = pd.read_csv(file_path, names=['Run', 'FileName', 'OptimizationLevel', 'NumThreads', 'TimeSec'], header=None)
data['TimeSec'] = data['TimeSec'].str.replace(' sec', '').astype(float)

# %%
# Filter for a specific run
specific_run_data = data[data['Run'] == 5]

# Execution time by number of threads for a specific run
sns.lineplot(x='NumThreads', y='TimeSec', hue='OptimizationLevel', data=specific_run_data, errorbar=None)
plt.title('Execution Time by Number of Threads (Run 1)')
plt.xlabel('Number of Threads')
plt.ylabel('Execution Time (sec)')
plt.legend(title='Optimization Level')
plt.show()

# Execution time by optimization level for a specific run
sns.boxplot(x='OptimizationLevel', y='TimeSec', data=specific_run_data)
plt.title('Execution Time by Optimization Level (Run 1)')
plt.xlabel('Optimization Level')
plt.ylabel('Execution Time (sec)')
plt.show()

# %%
# Calculate mean, std, min, and max for each group
stability_stats = data.groupby(['FileName', 'OptimizationLevel', 'NumThreads']).agg(['mean', 'std', 'min', 'max'])

# Assuming `stability_stats` is prepared with mean and std calculations
stability_stats = data.groupby(['OptimizationLevel', 'NumThreads']).agg(MeanTimeSec=('TimeSec', 'mean'), StdTimeSec=('TimeSec', 'std')).reset_index()

# Unique optimization levels and thread counts for plotting
optimization_levels = stability_stats['OptimizationLevel'].unique()
thread_counts = stability_stats['NumThreads'].unique()

# Prepare figure and axes for subplotting
fig, ax = plt.subplots(figsize=(10, 6))

for i, opt_lvl in enumerate(optimization_levels):
    # Filter data for each optimization level
    opt_data = stability_stats[stability_stats['OptimizationLevel'] == opt_lvl]
    
    # X positions for the bars
    x_pos = np.arange(len(thread_counts)) + i*(len(optimization_levels)+1)*0.1
    
    # Plot bars with error bars
    ax.bar(x_pos, opt_data['MeanTimeSec'], yerr=opt_data['StdTimeSec'], width=0.1, label=opt_lvl, capsize=5)

# Set the x-ticks to be the middle of each group of bars
ax.set_xticks(np.arange(len(thread_counts)) + 0.2)
ax.set_xticklabels(thread_counts)

ax.set_xlabel('Number of Threads')
ax.set_ylabel('Execution Time (sec)')
ax.set_title('Execution Time by Number of Threads with Error Bars')
ax.legend(title='Optimization Level')

plt.show()

# %%
# Group by NumThreads and OptimizationLevel, then find the minimum TimeSec
min_times_by_thread_and_opt = data.groupby(['NumThreads', 'OptimizationLevel']).agg(MinTimeSec=('TimeSec', 'min')).reset_index()

# Filter for 1 and 12 threads
threads_of_interest = [1, 12]
filtered_data = min_times_by_thread_and_opt[min_times_by_thread_and_opt['NumThreads'].isin(threads_of_interest)]

# Now, for each thread count of interest (1 and 12), find the entry with the minimum execution time
shortest_times = pd.DataFrame()
for thread in threads_of_interest:
    min_time_row = filtered_data[filtered_data['NumThreads'] == thread].nsmallest(1, 'MinTimeSec')
    shortest_times = pd.concat([shortest_times, min_time_row], ignore_index=True)

# Display the results, including the optimization level
print(shortest_times)
# Out:
#    NumThreads OptimizationLevel  MinTimeSec
# 0           1               -O2      0.0000
# 1          12               -O2      0.0002
